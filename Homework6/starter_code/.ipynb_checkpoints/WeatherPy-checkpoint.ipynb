# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import datetime
from scipy import stats

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
#Testing out new citipy library
oakland = citipy.nearest_city(37.8044, -122.2711)
print(oakland.city_name)
print(oakland.country_code)
# Out:
# oakland
# us

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)  #weather api may not have all the cities in our random list
# Out:
# 637

# %%
#check series
cities[100]
# Out:
# 'hobart'

# %%
#check weather api json format 
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "hobart"
 
query_url = url + "appid=" + api_key + "&q=" + city

#check url
print(query_url)

#json-ify api request
response = requests.get(query_url).json()

#check json
pprint(response)

#check weather data
print(f"city name: {response['name']}")
print(f"humidity: {response['main']['humidity']}")
print(f"latitude: {response['coord']['lat']}")
print(f"cloudiness: {response['clouds']['all']}")
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=679fa43e38b0c6228c8e1c7e7378c6ec&q=hobart
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -42.88, 'lon': 147.33},
#  'dt': 1554136996,
#  'id': 2163355,
#  'main': {'humidity': 87,
#           'pressure': 1025,
#           'temp': 279.64,
#           'temp_max': 280.93,
#           'temp_min': 278.15},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 9545,
#          'message': 0.0058,
#          'sunrise': 1554150428,
#          'sunset': 1554192091,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 330, 'speed': 3.6}}
# city name: Hobart
# humidity: 87
# latitude: -42.88
# cloudiness: 20

# %%
params = {"appid":api_key}
url = "http://api.openweathermap.org/data/2.5/weather?"

print("Beginning Data Retrieval")
print("------------------------")

for city in cities:
    
    params["q"] = city
    
    response = requests.get(url,params).json()
    
    try:
        print(f"Processing Record {cities.index(city)} | {response['name']}")
              
    except (KeyError, IndexError):
        print("City not found. Skipping...")

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#new container to hold cities within api call
unique_cities = []

#Set base URL and parameters
params = {"appid":api_key}
url = "http://api.openweathermap.org/data/2.5/weather?"

print("Beginning Data Retrieval")
print("------------------------")

#Loop through cities list and print index value and city name
for city in cities:
    
    #Pull in city from list
    params["q"] = city
    
    #query url with city
    response = requests.get(url,params).json()
    
    #print city and index value
    try:
        print(f"Processing Record {cities.index(city)} | {response['name']}")
        
        # If the city is in weather api, then add it to new unique cities list
        if city not in unique_cities:
            unique_cities.append(city)
    
    #if no city exist for the lng, lat, then skip
    except (KeyError, IndexError):
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# ------------------------
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 | Hithadhoo
# Processing Record 3 | Isperih
# Processing Record 4 | Ushuaia
# Processing Record 5 | Storforshei
# Processing Record 6 | Saint-Leu
# Processing Record 7 | Dongli
# Processing Record 8 | Gat
# Processing Record 9 | Bluff
# Processing Record 10 | Carnarvon
# Processing Record 11 | Pevek
# Processing Record 12 | Urucara
# City not found. Skipping...
# Processing Record 14 | Punta Arenas
# Processing Record 15 | Yellowknife
# Processing Record 16 | Mataura
# Processing Record 17 | Palmer
# Processing Record 18 | Jalu
# Processing Record 19 | Kloulklubed
# Processing Record 20 | Rikitea
# Processing Record 21 | Viedma
# Processing Record 22 | Pitea
# Processing Record 23 | Kerema
# Processing Record 24 | Castro
# Processing Record 25 | Talara
# Processing Record 26 | Margate
# Processing Record 27 | Bulgan
# Processing Record 28 | Ahuimanu
# City not found. Skipping...
# Processing Record 30 | New Norfolk
# Processing Record 31 | Jacareacanga
# Processing Record 32 | Vaini
# Processing Record 33 | Alta Floresta
# Processing Record 34 | Torbay
# Processing Record 35 | Akureyri
# Processing Record 36 | Albany
# Processing Record 37 | Hermanus
# Processing Record 38 | Barrow
# City not found. Skipping...
# Processing Record 40 | Berlevag
# Processing Record 41 | Barabai
# Processing Record 42 | Koslan
# Processing Record 43 | Loiza
# Processing Record 44 | Santa Cruz del Sur
# Processing Record 45 | Kropotkin
# Processing Record 46 | Busselton
# Processing Record 47 | Tasiilaq
# Processing Record 48 | Kostino
# Processing Record 49 | Geraldton
# Processing Record 50 | Cape Town
# Processing Record 51 | Mahebourg
# Processing Record 52 | Pacific Grove
# Processing Record 53 | Jamestown
# Processing Record 54 | Bloemhof
# Processing Record 55 | Kayes
# City not found. Skipping...
# Processing Record 57 | Lagoa
# Processing Record 58 | Mecca
# City not found. Skipping...
# Processing Record 60 | Tallahassee
# Processing Record 61 | Saldanha
# Processing Record 62 | Bethel
# Processing Record 63 | Kaitangata
# Processing Record 64 | Alofi
# Processing Record 65 | Port Hedland
# Processing Record 66 | Hvide Sande
# Processing Record 67 | Avarua
# Processing Record 68 | Plomarion
# Processing Record 69 | Marsa Matruh
# Processing Record 70 | Bambous Virieux
# Processing Record 71 | Bilma
# Processing Record 72 | Faya
# Processing Record 73 | Kholtoson
# Processing Record 74 | Thompson
# Processing Record 75 | Coahuayana
# City not found. Skipping...
# Processing Record 77 | Hualmay
# Processing Record 78 | Nacimiento
# Processing Record 79 | Belmonte
# Processing Record 80 | Kalispell
# Processing Record 81 | Marawi
# Processing Record 82 | Arraial do Cabo
# Processing Record 83 | Longyearbyen
# Processing Record 84 | Dubbo
# Processing Record 85 | Konstantinovka
# Processing Record 86 | Ponta do Sol
# Processing Record 87 | Bar Harbor
# Processing Record 88 | Narsaq
# Processing Record 89 | Zavoronezhskoye
# Processing Record 90 | Razdolnoye
# Processing Record 91 | Moose Factory
# Processing Record 92 | Port Hueneme
# Processing Record 93 | Botad
# Processing Record 94 | Puerto Ayora
# City not found. Skipping...
# Processing Record 96 | Cidreira
# Processing Record 97 | Bilibino
# City not found. Skipping...
# Processing Record 99 | Lorengau
# Processing Record 100 | Hobart
# City not found. Skipping...
# Processing Record 102 | Mogadishu
# Processing Record 103 | Hayden
# Processing Record 104 | Cremona
# Processing Record 105 | Hilo
# Processing Record 106 | Fuling
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 109 | Butaritari
# Processing Record 110 | Avera
# Processing Record 111 | Cabedelo
# Processing Record 112 | Road Town
# City not found. Skipping...
# Processing Record 114 | Xining
# Processing Record 115 | Port Alfred
# Processing Record 116 | Lambarene
# Processing Record 117 | Vostok
# Processing Record 118 | Qaanaaq
# Processing Record 119 | Ola
# Processing Record 120 | Rawson
# Processing Record 121 | Buala
# City not found. Skipping...
# Processing Record 123 | Tanete
# Processing Record 124 | Kavieng
# Processing Record 125 | Pumiao
# Processing Record 126 | Horodyshche
# Processing Record 127 | Ndago
# Processing Record 128 | Monrovia
# Processing Record 129 | Hirara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 132 | Catumbela
# Processing Record 133 | Hamilton
# Processing Record 134 | Pauini
# Processing Record 135 | Waitati
# Processing Record 136 | Fortuna
# Processing Record 137 | Hambantota
# Processing Record 138 | Merrill
# Processing Record 139 | Puliyur
# Processing Record 140 | Fort Nelson
# Processing Record 141 | Safranbolu
# Processing Record 142 | Ukiah
# Processing Record 143 | Clyde River
# Processing Record 144 | Atuona
# City not found. Skipping...
# Processing Record 146 | Saskylakh
# Processing Record 147 | Pedro Carbo
# Processing Record 148 | Talnakh
# Processing Record 149 | Banepa
# Processing Record 150 | Pierre
# Processing Record 151 | Port Elizabeth
# Processing Record 152 | Ushtobe
# Processing Record 153 | Chapais
# Processing Record 154 | Buchanan
# Processing Record 155 | Zenzeli
# Processing Record 156 | Khatanga
# Processing Record 157 | Caravelas
# Processing Record 158 | Plettenberg Bay
# Processing Record 159 | Airai
# Processing Record 160 | Maningrida
# Processing Record 161 | Cayenne
# Processing Record 162 | Kashiba
# Processing Record 163 | Qandala
# Processing Record 164 | Vao
# Processing Record 165 | Santa Marinella
# Processing Record 166 | Nikolskoye
# City not found. Skipping...
# Processing Record 168 | Nara
# Processing Record 169 | Beyneu
# City not found. Skipping...
# Processing Record 171 | Shediac
# Processing Record 172 | Kaduqli
# Processing Record 173 | Ulladulla
# Processing Record 174 | Ahipara
# Processing Record 175 | Dawson Creek
# Processing Record 176 | Georgetown
# City not found. Skipping...
# Processing Record 178 | Sitka
# Processing Record 179 | Vanimo
# City not found. Skipping...
# Processing Record 181 | Kapaa
# Processing Record 182 | Mayumba
# Processing Record 183 | Campos Belos
# Processing Record 184 | Taos
# Processing Record 185 | Yarmouth
# Processing Record 186 | Saint-Joseph
# Processing Record 187 | Grand Gaube
# Processing Record 188 | Rio Grande
# Processing Record 189 | Palu
# City not found. Skipping...
# Processing Record 191 | Erzin
# Processing Record 192 | Wagga Wagga
# Processing Record 193 | Abhar
# City not found. Skipping...
# Processing Record 195 | East London
# Processing Record 196 | Chokurdakh
# Processing Record 197 | Lasa
# Processing Record 198 | Labuhan
# Processing Record 199 | Upernavik
# Processing Record 200 | Esso
# Processing Record 201 | Flin Flon
# Processing Record 202 | Sorland
# Processing Record 203 | Todos Santos
# Processing Record 204 | Mount Pleasant
# Processing Record 205 | Talcahuano
# Processing Record 206 | Nantucket
# Processing Record 207 | Gambela
# Processing Record 208 | Kahului
# Processing Record 209 | Diamantino
# Processing Record 210 | Kudahuvadhoo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 213 | Puerto Baquerizo Moreno
# Processing Record 214 | Clarence Town
# Processing Record 215 | Albert Lea
# Processing Record 216 | Kaeo
# Processing Record 217 | Haapiti
# Processing Record 218 | Bredasdorp
# Processing Record 219 | Katsuura
# Processing Record 220 | El Pedernal
# Processing Record 221 | Hirado
# Processing Record 222 | Milkovo
# Processing Record 223 | Aberdeen
# Processing Record 224 | Dangriga
# Processing Record 225 | Payo
# Processing Record 226 | Tarakan
# Processing Record 227 | Adrar
# Processing Record 228 | Ancud
# Processing Record 229 | Ibra
# Processing Record 230 | Anan
# Processing Record 231 | Methoni
# City not found. Skipping...
# Processing Record 233 | Tuktoyaktuk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 236 | Port Lincoln
# Processing Record 237 | Acapulco
# Processing Record 238 | Okhotsk
# Processing Record 239 | Boyolangu
# Processing Record 240 | Ambon
# Processing Record 241 | Prince Rupert
# Processing Record 242 | Norman Wells
# Processing Record 243 | Iqaluit
# Processing Record 244 | Yanam
# Processing Record 245 | Ilulissat
# Processing Record 246 | Havre-Saint-Pierre
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 249 | Huntsville
# Processing Record 250 | Morro Bay
# Processing Record 251 | Hami
# Processing Record 252 | Ramganj Mandi
# Processing Record 253 | Muli
# Processing Record 254 | Porto Velho
# Processing Record 255 | Charters Towers
# Processing Record 256 | Gravdal
# Processing Record 257 | Pyshchug
# Processing Record 258 | Victoria
# Processing Record 259 | Xingcheng
# Processing Record 260 | Nouadhibou
# City not found. Skipping...
# Processing Record 262 | Fairbanks
# Processing Record 263 | Sorong
# City not found. Skipping...
# Processing Record 265 | Mehran
# Processing Record 266 | Sistranda
# Processing Record 267 | Merauke
# Processing Record 268 | Meulaboh
# Processing Record 269 | Westport
# Processing Record 270 | Ixtapa
# Processing Record 271 | Quatre Cocos
# Processing Record 272 | Sept-Iles
# Processing Record 273 | Kodiak
# Processing Record 274 | Souillac
# Processing Record 275 | High Rock
# Processing Record 276 | Moorpark
# Processing Record 277 | Marienburg
# Processing Record 278 | Cherskiy
# Processing Record 279 | Leningradskiy
# Processing Record 280 | Cacapava do Sul
# Processing Record 281 | Lebu
# Processing Record 282 | Hasaki
# Processing Record 283 | Luderitz
# Processing Record 284 | Tuatapere
# Processing Record 285 | Rock Sound
# Processing Record 286 | Kavaratti
# Processing Record 287 | Japura
# Processing Record 288 | Baculin
# Processing Record 289 | Luohe
# Processing Record 290 | Severo-Kurilsk
# Processing Record 291 | Eichstatt
# Processing Record 292 | Muzhi
# Processing Record 293 | Nome
# Processing Record 294 | Umm Lajj
# Processing Record 295 | Broome
# Processing Record 296 | Chirkey
# Processing Record 297 | Portland
# Processing Record 298 | Cabo San Lucas
# Processing Record 299 | Arica
# Processing Record 300 | Provideniya
# Processing Record 301 | Dwarka
# City not found. Skipping...
# Processing Record 303 | Mehamn
# Processing Record 304 | Axim
# Processing Record 305 | Vardo
# Processing Record 306 | Ures
# Processing Record 307 | Eyl
# Processing Record 308 | Aracuai
# Processing Record 309 | Port Hardy
# Processing Record 310 | Shiringushi
# Processing Record 311 | Umm Kaddadah
# Processing Record 312 | Bubaque
# Processing Record 313 | Gigmoto
# Processing Record 314 | Sarakhs
# Processing Record 315 | Bethal
# Processing Record 316 | Novoagansk
# Processing Record 317 | Chuy
# Processing Record 318 | Marbella
# Processing Record 319 | Kieta
# Processing Record 320 | Omidiyeh
# Processing Record 321 | Vila do Maio
# Processing Record 322 | Macia
# Processing Record 323 | Jackville
# Processing Record 324 | Dicabisagan
# Processing Record 325 | Henties Bay
# City not found. Skipping...
# Processing Record 327 | Santa Maria
# Processing Record 328 | Ribeira Grande
# Processing Record 329 | Saint George
# Processing Record 330 | Codrington
# Processing Record 331 | Dingle
# City not found. Skipping...
# Processing Record 333 | Hovd
# Processing Record 334 | Saryg-Sep
# Processing Record 335 | Inongo
# Processing Record 336 | Contamana
# Processing Record 337 | Araouane
# Processing Record 338 | Luwuk
# Processing Record 339 | Mahanoro
# Processing Record 340 | Bayji
# Processing Record 341 | Horki
# Processing Record 342 | Teguldet
# City not found. Skipping...
# Processing Record 344 | Dali
# Processing Record 345 | Alice Springs
# Processing Record 346 | Nalut
# Processing Record 347 | Mitchell
# Processing Record 348 | Kruisfontein
# Processing Record 349 | Ostrovnoy
# Processing Record 350 | Moranbah
# Processing Record 351 | Seoul
# Processing Record 352 | Yerofey Pavlovich
# Processing Record 353 | Panguna
# Processing Record 354 | Coalinga
# Processing Record 355 | Bonavista
# Processing Record 356 | Ranong
# Processing Record 357 | Touros
# Processing Record 358 | Yulara
# Processing Record 359 | Sao Filipe
# Processing Record 360 | Quelimane
# Processing Record 361 | Arman
# Processing Record 362 | Bridlington
# Processing Record 363 | Strezhevoy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 366 | Paramonga
# Processing Record 367 | Dipalpur
# Processing Record 368 | Mulege
# Processing Record 369 | Plouzane
# Processing Record 370 | San Matias
# Processing Record 371 | Soyo
# Processing Record 372 | Stepnyak
# Processing Record 373 | Sao Joao da Barra
# Processing Record 374 | Tashtagol
# Processing Record 375 | Loreto
# City not found. Skipping...
# Processing Record 377 | Santa Fe
# Processing Record 378 | Glendive
# Processing Record 379 | Yakeshi
# Processing Record 380 | Aitape
# Processing Record 381 | Cave Spring
# Processing Record 382 | Praia da Vitoria
# Processing Record 383 | Faanui
# Processing Record 384 | Kachug
# Processing Record 385 | Lavrentiya
# Processing Record 386 | Jinxi
# Processing Record 387 | Baijiantan
# Processing Record 388 | Esperance
# Processing Record 389 | Eydhafushi
# City not found. Skipping...
# Processing Record 391 | San Quintin
# City not found. Skipping...
# Processing Record 393 | Aklavik
# Processing Record 394 | Batagay-Alyta
# Processing Record 395 | Zelenoborsk
# Processing Record 396 | The Valley
# Processing Record 397 | Honningsvag
# Processing Record 398 | Qaqortoq
# Processing Record 399 | Mar del Plata
# Processing Record 400 | Vuktyl
# Processing Record 401 | Aswan
# Processing Record 402 | Illapel
# Processing Record 403 | Veraval
# Processing Record 404 | Mahajanga
# Processing Record 405 | Tezu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 408 | Marsh Harbour
# Processing Record 409 | Villa Maria
# Processing Record 410 | Peniche
# Processing Record 411 | Tiksi
# Processing Record 412 | Verkh-Usugli
# City not found. Skipping...
# Processing Record 414 | San Roque
# Processing Record 415 | Lufilufi
# Processing Record 416 | Lata
# Processing Record 417 | Tevriz
# Processing Record 418 | Kalmunai
# Processing Record 419 | Bambanglipuro
# Processing Record 420 | Lashio
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 423 | Caririacu
# Processing Record 424 | Coquimbo
# Processing Record 425 | Klaksvik
# Processing Record 426 | Phalombe
# City not found. Skipping...
# Processing Record 428 | Cabanas
# Processing Record 429 | Constitucion
# City not found. Skipping...
# Processing Record 431 | Priyutnoye
# City not found. Skipping...
# Processing Record 433 | Vryburg
# City not found. Skipping...
# Processing Record 435 | Beringovskiy
# Processing Record 436 | Borogontsy
# City not found. Skipping...
# Processing Record 438 | Khani
# Processing Record 439 | San Patricio
# Processing Record 440 | Bloemfontein
# Processing Record 441 | Trelew
# Processing Record 442 | Bonito
# Processing Record 443 | Coachella
# Processing Record 444 | Te Anau
# Processing Record 445 | Deputatskiy
# Processing Record 446 | Terney
# Processing Record 447 | Batticaloa
# Processing Record 448 | Umba
# City not found. Skipping...
# Processing Record 450 | Tautira
# Processing Record 451 | Natal
# Processing Record 452 | Padang
# Processing Record 453 | Leshukonskoye
# Processing Record 454 | Takhtamukay
# Processing Record 455 | Ajdabiya
# City not found. Skipping...
# Processing Record 457 | Bogande
# Processing Record 458 | Soja
# City not found. Skipping...
# Processing Record 460 | Farafangana
# Processing Record 461 | Roald
# City not found. Skipping...
# Processing Record 463 | Chicama
# Processing Record 464 | Ulagan
# Processing Record 465 | Skerries
# Processing Record 466 | Huntingdon
# Processing Record 467 | Ossora
# Processing Record 468 | Nizhniy Odes
# Processing Record 469 | Vaitape
# City not found. Skipping...
# Processing Record 471 | Formosa
# Processing Record 472 | Kawalu
# Processing Record 473 | Chitipa
# Processing Record 474 | Salalah
# Processing Record 475 | Nanortalik
# Processing Record 476 | Erenhot
# Processing Record 477 | Tessalit
# Processing Record 478 | Port-Cartier
# Processing Record 479 | Chernyshevskiy
# Processing Record 480 | Shuangcheng
# City not found. Skipping...
# Processing Record 482 | Maposeni
# Processing Record 483 | Bathsheba
# Processing Record 484 | Wainwright
# Processing Record 485 | Srednekolymsk
# Processing Record 486 | Balkhash
# City not found. Skipping...
# Processing Record 488 | Bongouanou
# Processing Record 489 | Haines Junction
# Processing Record 490 | Nordenham
# Processing Record 491 | Husavik
# City not found. Skipping...
# Processing Record 493 | Les Cayes
# Processing Record 494 | Middle Island
# Processing Record 495 | San Rafael del Sur
# Processing Record 496 | Andapa
# Processing Record 497 | Dutse
# Processing Record 498 | Siva
# City not found. Skipping...
# Processing Record 500 | Kondagaon
# City not found. Skipping...
# Processing Record 502 | Betare Oya
# Processing Record 503 | Ryotsu
# City not found. Skipping...
# Processing Record 505 | Comodoro Rivadavia
# Processing Record 506 | Mackay
# Processing Record 507 | Prado
# Processing Record 508 | Petawawa
# Processing Record 509 | San Vicente
# Processing Record 510 | Walvis Bay
# Processing Record 511 | Goure
# Processing Record 512 | Magdagachi
# Processing Record 513 | Havoysund
# Processing Record 514 | Mayna
# Processing Record 515 | Gizo
# Processing Record 516 | Nacogdoches
# Processing Record 517 | Amapa
# Processing Record 518 | Novosokolniki
# Processing Record 519 | Yumen
# Processing Record 520 | Tashla
# Processing Record 521 | Shimoda
# Processing Record 522 | Naryan-Mar
# Processing Record 523 | Komsomolskiy
# Processing Record 524 | Sao Geraldo do Araguaia
# Processing Record 525 | Smithers
# Processing Record 526 | Puerto Escondido
# Processing Record 527 | Ostersund
# Processing Record 528 | Makakilo City
# Processing Record 529 | Allanridge
# Processing Record 530 | Chandia
# Processing Record 531 | Mumford
# Processing Record 532 | Caconda
# Processing Record 533 | Almaznyy
# Processing Record 534 | Luchenza
# Processing Record 535 | Mitake
# Processing Record 536 | Kysyl-Syr
# City not found. Skipping...
# Processing Record 538 | Qarqin
# Processing Record 539 | Howick
# Processing Record 540 | Pitimbu
# Processing Record 541 | Toora-Khem
# Processing Record 542 | Zykovo
# Processing Record 543 | Praia
# Processing Record 544 | Necochea
# Processing Record 545 | Washington DC.
# Processing Record 546 | Luba
# Processing Record 547 | La Romana
# Processing Record 548 | Baruun-Urt
# Processing Record 549 | Saurimo
# City not found. Skipping...
# Processing Record 551 | Changji
# Processing Record 552 | Vestmanna
# Processing Record 553 | Bodden Town
# Processing Record 554 | Champerico
# Processing Record 555 | Kulhudhuffushi
# Processing Record 556 | Ouro Sogui
# Processing Record 557 | Sabang
# Processing Record 558 | Fuquay-Varina
# Processing Record 559 | Forbes
# Processing Record 560 | Ust-Nera
# Processing Record 561 | Alto Araguaia
# Processing Record 562 | Okahandja
# Processing Record 563 | Winnemucca
# Processing Record 564 | Manaus
# Processing Record 565 | Karratha
# Processing Record 566 | Paamiut
# Processing Record 567 | Mayo
# Processing Record 568 | Manavalakurichi
# City not found. Skipping...
# Processing Record 570 | Puerto Colombia
# City not found. Skipping...
# Processing Record 572 | Balaipungut
# Processing Record 573 | Susanville
# Processing Record 574 | Pueblo
# Processing Record 575 | Bichura
# Processing Record 576 | Nemuro
# Processing Record 577 | Tamandare
# City not found. Skipping...
# Processing Record 579 | Goroka
# Processing Record 580 | Superior
# Processing Record 581 | Rafaela
# Processing Record 582 | Adilcevaz
# Processing Record 583 | Ayan
# Processing Record 584 | Manokwari
# Processing Record 585 | Azua
# Processing Record 586 | Polunochnoye
# Processing Record 587 | Kumta
# Processing Record 588 | Abu Dhabi
# Processing Record 589 | Pundaguitan
# Processing Record 590 | Baker City
# Processing Record 591 | Karpathos
# Processing Record 592 | Isiro
# City not found. Skipping...
# Processing Record 594 | Rundu
# Processing Record 595 | Mariakani
# Processing Record 596 | Abu Samrah
# Processing Record 597 | Grindavik
# Processing Record 598 | Biak
# Processing Record 599 | Inhambane
# Processing Record 600 | Northam
# Processing Record 601 | Visnes
# Processing Record 602 | Bani Walid
# Processing Record 603 | Mocuba
# Processing Record 604 | Ende
# Processing Record 605 | Port Huron
# Processing Record 606 | Hofn
# Processing Record 607 | Aleksandro-Nevskiy
# Processing Record 608 | Nuuk
# Processing Record 609 | Kirakira
# Processing Record 610 | Porto Torres
# Processing Record 611 | Vallenar
# Processing Record 612 | Pochutla
# Processing Record 613 | Tupik
# Processing Record 614 | Yarada
# Processing Record 615 | Banda Aceh
# Processing Record 616 | Dubrovnik
# Processing Record 617 | Sur
# Processing Record 618 | Acajutla
# Processing Record 619 | Semey
# Processing Record 620 | Salinopolis
# City not found. Skipping...
# Processing Record 622 | Dikson
# Processing Record 623 | Presidencia Roque Saenz Pena
# City not found. Skipping...
# Processing Record 625 | Kharagpur
# Processing Record 626 | Paragominas
# Processing Record 627 | Najran
# Processing Record 628 | Chulym
# Processing Record 629 | Havelock
# Processing Record 630 | Kaukauna
# Processing Record 631 | Itarema
# Processing Record 632 | Novichikha
# Processing Record 633 | Ulaangom
# City not found. Skipping...
# Processing Record 635 | Arrah
# Processing Record 636 | Senanga

# %%
#check number of cities in clean city list
len(unique_cities)
# Out:
# 565

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create data frame from cities list
weather_df = pd.DataFrame(unique_cities)
weather_df = weather_df.rename(columns={0:"city"})

#set containers in new weather dataframe to hold json values
weather_df["city_id"] = ""
weather_df["date"] = ""
weather_df["lat"] = ""
weather_df["lon"] = ""
weather_df["country"] = ""
weather_df["maxTemp"] = ""
weather_df["cloudiness"] = ""
weather_df["humidity"] = ""
weather_df["windSpeed"] = ""

#display empty dataframe
weather_df.head()
# Out:
#           city city_id date lat lon country maxTemp cloudiness humidity  \
# 0    hithadhoo
# 1      isperih
# 2      ushuaia
# 3  storforshei
# 4    saint-leu
#
#   windSpeed
# 0
# 1
# 2
# 3
# 4

# %%
#Set base URL and parameters
params = {"appid":api_key}
url = "http://api.openweathermap.org/data/2.5/weather?"

#Loop through clean cities list and append values for plot
for index,row in weather_df.iterrows():
    
    #Pull in city from list
    params["q"] = row['city']
    
    #query url with city
    response = requests.get(url,params).json()
    
    #append weather data to dataframe

    weather_df.loc[index,"city_id"] = response['id']
    weather_df.loc[index,"date"] = time.strftime("%d %b %Y", time.localtime(response['dt'])) 
    weather_df.loc[index,"lat"] = response['coord']['lat']
    weather_df.loc[index,"lon"] = response['coord']['lon']
    weather_df.loc[index,"country"] = response['sys']['country']
    weather_df.loc[index,"maxTemp"] = response['main']['temp_max']
    weather_df.loc[index,"cloudiness"] = response['clouds']['all']
    weather_df.loc[index,"humidity"] = response['main']['humidity']
    weather_df.loc[index,"windSpeed"] = response['wind']['speed']

# %%
#display full populated dataframe
weather_df.head()
# Out:
#           city  city_id         date    lat    lon country maxTemp cloudiness  \
# 0    hithadhoo  1282256  01 Apr 2019   -0.6  73.08      MV   301.8         76
# 1      isperih   730866  01 Apr 2019  43.72  26.83      BG  288.71         80
# 2      ushuaia  3833367  01 Apr 2019 -54.81 -68.31      AR  284.15         90
# 3  storforshei  3145614  01 Apr 2019   66.4  14.52      NO  276.15         75
# 4    saint-leu  6690297  01 Apr 2019 -21.15  55.28      RE  300.15          0
#
#   humidity windSpeed
# 0      100      2.72
# 1       37      4.02
# 2       93       4.1
# 3       93       4.1
# 4       74       1.5

# %%
#convert to correct data type for analysis

float_list = ['lat','lon','maxTemp','windSpeed']
int_list = ['cloudiness','humidity']

for column in float_list:
    weather_df[column] = weather_df[column].astype(float)
for column in int_list:
    weather_df[column] = weather_df[column].astype(int)

#check data types
weather_df.dtypes
# Out:
# city           object
# city_id        object
# date           object
# lat           float64
# lon           float64
# country        object
# maxTemp       float64
# cloudiness      int64
# humidity        int64
# windSpeed     float64
# dtype: object

# %%
#Export weather data to csv
weather_df.to_csv("output_data/weather_01Apr2019_sample.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['lat'],weather_df['maxTemp'],marker='o',edgecolor='black')
plt.grid()
today_dt = datetime.datetime.now()
plt.title(f"City Latitude vs Max Temperature ({today_dt.strftime('%d %b %Y')}) \n Sample of 565 Cities")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("output_data/fig1_MaxTemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['lat'],weather_df['humidity'],marker='o',edgecolor='black')
plt.grid()
plt.title(f"City Latitude vs Humidity ({today_dt.strftime('%d %b %Y')}) \n Sample of 565 Cities")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("output_data/fig2_Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['lat'],weather_df['cloudiness'],marker='o',edgecolor='black')
plt.grid()
plt.title(f"City Latitude vs Cloudiness ({today_dt.strftime('%d %b %Y')}) \n Sample of 565 Cities")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("output_data/fig3_Cloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['lat'],weather_df['windSpeed'],marker='o',edgecolor='black')
plt.grid()
plt.title(f"City Latitude vs Wind Speed({today_dt.strftime('%d %b %Y')}) \n Sample of 565 Cities")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("output_data/fig4_WindSpeed.png")
plt.show()

# %% [markdown]
# #### Analysis

# %%
#There is an outlier (check the city with humidity > 200%)
weather_df[weather_df["humidity"]>200]
# Out:
#       city  city_id         date   lat    lon country  maxTemp  cloudiness  \
# 22  talara  3691582  01 Apr 2019 -4.58 -81.27      PE   290.15          40
#
#     humidity  windSpeed
# 22       290       3.84

# %%
#Descriptive stats
weather_df.describe()
# Out:
#               lat         lon     maxTemp  cloudiness    humidity   windSpeed
# count  565.000000  565.000000  565.000000  565.000000  565.000000  565.000000
# mean    20.836248   15.296920  287.987115   37.122124   70.644248    3.488920
# std     32.536534   88.582501   12.972803   34.798523   23.852661    2.236124
# min    -54.810000 -173.230000  248.000000    0.000000   10.000000    0.140000
# 25%     -5.810000  -64.550000  277.800000    0.000000   58.000000    1.720000
# 50%     24.180000   22.130000  290.150000   24.000000   72.000000    3.070000
# 75%     47.990000   87.850000  299.300000   75.000000   88.000000    4.620000
# max     78.220000  179.320000  315.150000  100.000000  290.000000   12.900000
