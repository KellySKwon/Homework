# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import datetime
from scipy import stats

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
#Testing out new citipy library
oakland = citipy.nearest_city(37.8044, -122.2711)
print(oakland.city_name)
print(oakland.country_code)
# Out:
# oakland
# us

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)  #weather api may not have all the cities in our random list
# Out:
# 561

# %%
#check series
cities[100]
# Out:
# 'kyren'

# %%
#check weather api json format 
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "kyren"
units = "imperial"
 
query_url = url + "appid=" + api_key + "&q=" + city + "&units=" + units

#check url
print(query_url)

#json-ify api request
response = requests.get(query_url).json()

#check json
pprint(response)

#check weather data
print(f"city name: {response['name']}")
print(f"humidity: {response['main']['humidity']}")
print(f"latitude: {response['coord']['lat']}")
print(f"cloudiness: {response['clouds']['all']}")
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=679fa43e38b0c6228c8e1c7e7378c6ec&q=kyren&units=imperial
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 51.68, 'lon': 102.13},
#  'dt': 1554150188,
#  'id': 2021031,
#  'main': {'grnd_level': 848.12,
#           'humidity': 63,
#           'pressure': 1028.22,
#           'sea_level': 1028.22,
#           'temp': 13.39,
#           'temp_max': 13.39,
#           'temp_min': 13.39},
#  'name': 'Kyren',
#  'sys': {'country': 'RU',
#          'message': 0.0034,
#          'sunrise': 1554158744,
#          'sunset': 1554205465},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 282, 'speed': 1.7}}
# city name: Kyren
# humidity: 63
# latitude: 51.68
# cloudiness: 48

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#new container to hold cities within api call
unique_cities = []

#Set base URL and parameters
params = {"appid":api_key,"units":"imperial"}
url = "http://api.openweathermap.org/data/2.5/weather?"

print("Beginning Data Retrieval")
print("------------------------")

#Loop through cities list and print index value and city name
for city in cities:
    
    #Pull in city from list
    params["q"] = city
    
    #query url with city
    response = requests.get(url,params).json()
    
    #print city and index value
    try:
        print(f"Processing Record {cities.index(city)} | {response['name']}")
        
        # If the city is in weather api, then add it to new unique cities list
        if city not in unique_cities:
            unique_cities.append(city)
    
    #if no city exist for the lng, lat, then skip
    except (KeyError, IndexError):
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 0 | Hasaki
# Processing Record 1 | Fairbanks
# Processing Record 2 | Airai
# Processing Record 3 | Balkanabat
# Processing Record 4 | Lagoa
# Processing Record 5 | La Paz
# Processing Record 6 | Wanning
# Processing Record 7 | Nhulunbuy
# Processing Record 8 | Khandyga
# Processing Record 9 | Khanna
# Processing Record 10 | Atuona
# Processing Record 11 | Rikitea
# Processing Record 12 | Honiara
# Processing Record 13 | Ushuaia
# Processing Record 14 | Qaanaaq
# Processing Record 15 | Nome
# Processing Record 16 | Mataura
# Processing Record 17 | Waipawa
# Processing Record 18 | Jamestown
# Processing Record 19 | Yima
# Processing Record 20 | Salalah
# Processing Record 21 | Chokurdakh
# Processing Record 22 | Hobart
# City not found. Skipping...
# Processing Record 24 | Port Alfred
# Processing Record 25 | Yellowknife
# Processing Record 26 | Victoria
# Processing Record 27 | East London
# Processing Record 28 | Labuhan
# City not found. Skipping...
# Processing Record 30 | Faanui
# Processing Record 31 | Tiksi
# Processing Record 32 | Ribeira Grande
# City not found. Skipping...
# Processing Record 34 | Hermanus
# City not found. Skipping...
# Processing Record 36 | Busselton
# City not found. Skipping...
# Processing Record 38 | Los Llanos de Aridane
# Processing Record 39 | Syracuse
# Processing Record 40 | Santa Maria
# City not found. Skipping...
# Processing Record 42 | Bredasdorp
# Processing Record 43 | Saint-Philippe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 | Butaritari
# Processing Record 47 | Avarua
# Processing Record 48 | Georgetown
# Processing Record 49 | Lompoc
# Processing Record 50 | Hithadhoo
# Processing Record 51 | Kaeo
# Processing Record 52 | Petropavlovsk-Kamchatskiy
# Processing Record 53 | Leningradskiy
# Processing Record 54 | Shache
# Processing Record 55 | Dharmavaram
# Processing Record 56 | Port Blair
# Processing Record 57 | Vetluga
# Processing Record 58 | Gabu
# Processing Record 59 | Bluff
# Processing Record 60 | Kaitangata
# Processing Record 61 | Nikolskoye
# Processing Record 62 | Punta Arenas
# Processing Record 63 | Kichera
# City not found. Skipping...
# Processing Record 65 | Chuy
# Processing Record 66 | Vaini
# Processing Record 67 | Arraial do Cabo
# Processing Record 68 | Sao Joao da Barra
# City not found. Skipping...
# Processing Record 70 | Salinas
# Processing Record 71 | Tuatapere
# Processing Record 72 | Adoni
# Processing Record 73 | San Cristobal
# Processing Record 74 | Cape Town
# Processing Record 75 | Sept-Iles
# Processing Record 76 | Culebra
# Processing Record 77 | Dicabisagan
# Processing Record 78 | Vanimo
# Processing Record 79 | Castro
# Processing Record 80 | Ponerihouen
# Processing Record 81 | Karratha
# Processing Record 82 | Posse
# Processing Record 83 | Hopelchen
# Processing Record 84 | Klaksvik
# Processing Record 85 | Albany
# Processing Record 86 | Savannah Bight
# Processing Record 87 | Saint-Joseph
# Processing Record 88 | Hilo
# Processing Record 89 | Tasiilaq
# City not found. Skipping...
# Processing Record 91 | Seoul
# Processing Record 92 | Phimai
# Processing Record 93 | Upernavik
# Processing Record 94 | Meulaboh
# Processing Record 95 | Huarmey
# Processing Record 96 | Pangody
# Processing Record 97 | Kapaa
# Processing Record 98 | Mae Hong Son
# City not found. Skipping...
# Processing Record 100 | Kyren
# Processing Record 101 | Tual
# Processing Record 102 | Chicama
# Processing Record 103 | Namie
# Processing Record 104 | Victor Harbor
# Processing Record 105 | Ankara
# Processing Record 106 | Bulungu
# Processing Record 107 | Pevek
# Processing Record 108 | Wageningen
# Processing Record 109 | Ixtapa
# Processing Record 110 | Tursunzoda
# City not found. Skipping...
# Processing Record 112 | Puerto Escondido
# City not found. Skipping...
# Processing Record 114 | Bethel
# Processing Record 115 | Verkhnevilyuysk
# Processing Record 116 | Puerto Ayora
# Processing Record 117 | Dunedin
# Processing Record 118 | Gazanjyk
# Processing Record 119 | San Patricio
# Processing Record 120 | Bakel
# Processing Record 121 | Dikson
# Processing Record 122 | Bambous Virieux
# City not found. Skipping...
# Processing Record 124 | Lorengau
# Processing Record 125 | Dingle
# Processing Record 126 | Najran
# Processing Record 127 | Basco
# Processing Record 128 | Kaduqli
# Processing Record 129 | Alta Floresta
# Processing Record 130 | Namibe
# City not found. Skipping...
# Processing Record 132 | Nouadhibou
# Processing Record 133 | Darhan
# Processing Record 134 | Grindavik
# Processing Record 135 | Sisimiut
# Processing Record 136 | Buala
# Processing Record 137 | Sorland
# Processing Record 138 | Ciudad Bolivar
# Processing Record 139 | Sitka
# Processing Record 140 | Sao Filipe
# Processing Record 141 | Baykalovo
# Processing Record 142 | Cururupu
# Processing Record 143 | Tezu
# Processing Record 144 | Luderitz
# City not found. Skipping...
# Processing Record 146 | Longyearbyen
# Processing Record 147 | Luanda
# Processing Record 148 | Nago
# Processing Record 149 | Lasa
# Processing Record 150 | Mahebourg
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 153 | Tuktoyaktuk
# Processing Record 154 | Haines Junction
# Processing Record 155 | Baghdad
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 158 | Kavieng
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 161 | Sindor
# Processing Record 162 | Hay River
# Processing Record 163 | Bonfim
# Processing Record 164 | Ancud
# Processing Record 165 | Ponta do Sol
# Processing Record 166 | Carnarvon
# Processing Record 167 | Merauke
# Processing Record 168 | Beira
# Processing Record 169 | Araceli
# Processing Record 170 | Kodiak
# Processing Record 171 | Chapais
# Processing Record 172 | Fortuna
# Processing Record 173 | San Pedro
# Processing Record 174 | Kruisfontein
# Processing Record 175 | Iqaluit
# Processing Record 176 | Severo-Kurilsk
# Processing Record 177 | Moyuta
# Processing Record 178 | Mar del Plata
# Processing Record 179 | Rio Gallegos
# Processing Record 180 | Port Lincoln
# Processing Record 181 | Ilulissat
# Processing Record 182 | Manicore
# Processing Record 183 | Launceston
# Processing Record 184 | Aklavik
# Processing Record 185 | Denpasar
# Processing Record 186 | Conde
# Processing Record 187 | Maamba
# Processing Record 188 | Taksimo
# Processing Record 189 | Half Moon Bay
# Processing Record 190 | Ardakan
# Processing Record 191 | Homer
# Processing Record 192 | Barrow
# Processing Record 193 | Senneterre
# Processing Record 194 | Nanortalik
# Processing Record 195 | Daia
# Processing Record 196 | Yugorsk
# Processing Record 197 | Tazmalt
# Processing Record 198 | Tarakan
# Processing Record 199 | Salvador
# Processing Record 200 | Dabhol
# Processing Record 201 | Port Elizabeth
# Processing Record 202 | Cidreira
# City not found. Skipping...
# Processing Record 204 | Charters Towers
# Processing Record 205 | Geraldton
# Processing Record 206 | Lebu
# Processing Record 207 | Kalininsk
# Processing Record 208 | Codrington
# Processing Record 209 | Puerto Narino
# Processing Record 210 | Huangzhai
# Processing Record 211 | Mattru
# Processing Record 212 | Clermont
# City not found. Skipping...
# Processing Record 214 | Barcelona
# Processing Record 215 | Takoradi
# Processing Record 216 | Arcelia
# Processing Record 217 | Halifax
# Processing Record 218 | Souillac
# Processing Record 219 | Phan Thiet
# Processing Record 220 | Swan Hill
# Processing Record 221 | Mascota
# Processing Record 222 | Ewa Beach
# Processing Record 223 | Nador
# Processing Record 224 | Itoman
# Processing Record 225 | Puksoozero
# Processing Record 226 | Fonte Boa
# Processing Record 227 | Fukue
# Processing Record 228 | Lavrentiya
# Processing Record 229 | Yelovo
# Processing Record 230 | Norman Wells
# Processing Record 231 | Katsuura
# Processing Record 232 | Megion
# Processing Record 233 | Tura
# City not found. Skipping...
# Processing Record 235 | Waitati
# Processing Record 236 | Deputatskiy
# Processing Record 237 | Clyde River
# Processing Record 238 | Isangel
# City not found. Skipping...
# Processing Record 240 | Juneau
# Processing Record 241 | Wajima
# City not found. Skipping...
# Processing Record 243 | Mopipi
# City not found. Skipping...
# Processing Record 245 | Rayagada
# Processing Record 246 | Narsaq
# Processing Record 247 | Lac-Megantic
# City not found. Skipping...
# Processing Record 249 | Hovd
# Processing Record 250 | Cherskiy
# City not found. Skipping...
# Processing Record 252 | Saskylakh
# Processing Record 253 | Beringovskiy
# Processing Record 254 | Arlit
# Processing Record 255 | Ambunti
# Processing Record 256 | Vila Franca do Campo
# Processing Record 257 | Maniitsoq
# Processing Record 258 | Igarka
# Processing Record 259 | Gararu
# Processing Record 260 | Cedro
# City not found. Skipping...
# Processing Record 262 | Lakatoro
# Processing Record 263 | Gazimurskiy Zavod
# Processing Record 264 | Padang
# Processing Record 265 | Makasar
# Processing Record 266 | Orange Cove
# Processing Record 267 | Cabo San Lucas
# City not found. Skipping...
# Processing Record 269 | Ritchie
# Processing Record 270 | Mehamn
# Processing Record 271 | Loudi
# Processing Record 272 | Rebrikha
# Processing Record 273 | Aksu
# Processing Record 274 | Garden City
# Processing Record 275 | Boyuibe
# Processing Record 276 | Viransehir
# Processing Record 277 | Kamphaeng Phet
# Processing Record 278 | Esperance
# Processing Record 279 | Itarema
# Processing Record 280 | Gumdag
# Processing Record 281 | Douentza
# Processing Record 282 | College
# Processing Record 283 | Upata
# Processing Record 284 | Jumla
# Processing Record 285 | Pangkalanbuun
# Processing Record 286 | Thompson
# Processing Record 287 | Brae
# Processing Record 288 | New Norfolk
# Processing Record 289 | North Bend
# Processing Record 290 | Caravelas
# Processing Record 291 | Morehead
# Processing Record 292 | Bathsheba
# Processing Record 293 | Tuma
# Processing Record 294 | Mbaiki
# Processing Record 295 | Egvekinot
# Processing Record 296 | Fernley
# Processing Record 297 | Russell
# Processing Record 298 | Guerrero Negro
# Processing Record 299 | Orotina
# Processing Record 300 | Verkhnyaya Inta
# Processing Record 301 | Saldanha
# Processing Record 302 | Guhagar
# Processing Record 303 | Oktyabrskiy
# Processing Record 304 | Goure
# Processing Record 305 | Westport
# Processing Record 306 | Okhotsk
# City not found. Skipping...
# Processing Record 308 | Makakilo City
# Processing Record 309 | Marienburg
# Processing Record 310 | Ahipara
# Processing Record 311 | Ponta Delgada
# Processing Record 312 | Birjand
# Processing Record 313 | Nelson Bay
# Processing Record 314 | Meadow Lake
# City not found. Skipping...
# Processing Record 316 | Tessalit
# Processing Record 317 | Marsh Harbour
# Processing Record 318 | Luziania
# Processing Record 319 | Fort Nelson
# Processing Record 320 | Vestmannaeyjar
# Processing Record 321 | Santa Isabel do Rio Negro
# Processing Record 322 | Ipaussu
# City not found. Skipping...
# Processing Record 324 | Mount Gambier
# Processing Record 325 | Inongo
# Processing Record 326 | Saint George
# Processing Record 327 | Yulara
# Processing Record 328 | Ginda
# Processing Record 329 | Killybegs
# Processing Record 330 | Amapa
# Processing Record 331 | Jacareacanga
# Processing Record 332 | Camocim
# Processing Record 333 | Florianopolis
# Processing Record 334 | Tecolutla
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 337 | Matagami
# Processing Record 338 | Hamilton
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 342 | Provideniya
# Processing Record 343 | Laurel
# Processing Record 344 | Bahia Blanca
# Processing Record 345 | Atambua
# Processing Record 346 | Mangan
# Processing Record 347 | Waingapu
# Processing Record 348 | Lander
# Processing Record 349 | Gao
# Processing Record 350 | Dovers
# City not found. Skipping...
# Processing Record 352 | Jieshi
# Processing Record 353 | Santiago de Cao
# Processing Record 354 | Beloha
# Processing Record 355 | Itacoatiara
# City not found. Skipping...
# Processing Record 357 | Saravan
# City not found. Skipping...
# Processing Record 359 | Twin Falls
# Processing Record 360 | Kiama
# Processing Record 361 | Comodoro Rivadavia
# Processing Record 362 | Hwange
# City not found. Skipping...
# Processing Record 364 | Terekli-Mekteb
# Processing Record 365 | Sri Aman
# Processing Record 366 | Chermoz
# Processing Record 367 | Meiganga
# Processing Record 368 | San Quintin
# Processing Record 369 | Bushehr
# Processing Record 370 | Kudahuvadhoo
# Processing Record 371 | Pacific Grove
# Processing Record 372 | Morro Bay
# Processing Record 373 | Keflavik
# Processing Record 374 | Necochea
# Processing Record 375 | Mandalgovi
# Processing Record 376 | La Rioja
# Processing Record 377 | Yuyao
# Processing Record 378 | Beni Mazar
# Processing Record 379 | Taltal
# Processing Record 380 | Amahai
# Processing Record 381 | Saint Anthony
# Processing Record 382 | Sechura
# Processing Record 383 | Bijar
# Processing Record 384 | Port Lavaca
# Processing Record 385 | Scarborough
# Processing Record 386 | Torbay
# Processing Record 387 | Elliot
# Processing Record 388 | Whakatane
# City not found. Skipping...
# Processing Record 390 | Kiruna
# City not found. Skipping...
# Processing Record 392 | Broome
# Processing Record 393 | Jiaonan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 396 | Inhambane
# Processing Record 397 | Flin Flon
# Processing Record 398 | Abnub
# City not found. Skipping...
# Processing Record 400 | Pierreville
# Processing Record 401 | Richards Bay
# Processing Record 402 | Coihaique
# Processing Record 403 | Yongan
# Processing Record 404 | Kahului
# Processing Record 405 | Zholymbet
# Processing Record 406 | Quatre Cocos
# Processing Record 407 | Poum
# Processing Record 408 | Kranea Elassonos
# Processing Record 409 | Port Macquarie
# City not found. Skipping...
# Processing Record 411 | Port Hardy
# Processing Record 412 | San Policarpo
# Processing Record 413 | Manokwari
# Processing Record 414 | Dongtai
# Processing Record 415 | Reo
# Processing Record 416 | Knysna
# Processing Record 417 | Kloulklubed
# Processing Record 418 | Itaituba
# Processing Record 419 | Dromolaxia
# Processing Record 420 | Cayenne
# Processing Record 421 | Cockburn Town
# Processing Record 422 | Ipixuna
# Processing Record 423 | Howard Springs
# Processing Record 424 | Zyryanka
# Processing Record 425 | Bad Windsheim
# Processing Record 426 | Xuddur
# Processing Record 427 | Jinchang
# City not found. Skipping...
# Processing Record 429 | Vao
# Processing Record 430 | Dallas
# Processing Record 431 | Pilar
# Processing Record 432 | Honningsvag
# Processing Record 433 | Vardo
# Processing Record 434 | Nieuw Amsterdam
# Processing Record 435 | Sur
# Processing Record 436 | Susanville
# Processing Record 437 | Severodvinsk
# Processing Record 438 | Usinsk
# Processing Record 439 | Khatanga
# Processing Record 440 | Fallon
# Processing Record 441 | Berlevag
# Processing Record 442 | Kecel
# Processing Record 443 | Dharchula
# Processing Record 444 | Berberati
# Processing Record 445 | Dudinka
# Processing Record 446 | Hervey Bay
# Processing Record 447 | Mildura
# Processing Record 448 | Gari
# Processing Record 449 | Gat
# Processing Record 450 | Lat Yao
# Processing Record 451 | Saint-Francois
# Processing Record 452 | Buluang
# Processing Record 453 | Kuusamo
# Processing Record 454 | Naze
# Processing Record 455 | Caxito
# Processing Record 456 | Kenai
# Processing Record 457 | Bonavista
# Processing Record 458 | Fairlie
# Processing Record 459 | Kozhva
# Processing Record 460 | Gloria do Goita
# Processing Record 461 | High Level
# Processing Record 462 | Shebunino
# Processing Record 463 | Rome
# Processing Record 464 | Puri
# Processing Record 465 | Lata
# Processing Record 466 | Gerash
# Processing Record 467 | Nuuk
# Processing Record 468 | Laguna
# Processing Record 469 | Lae
# Processing Record 470 | Linda
# City not found. Skipping...
# Processing Record 472 | Port-Gentil
# Processing Record 473 | Ocean City
# Processing Record 474 | Mahanoro
# Processing Record 475 | Chara
# Processing Record 476 | Touros
# Processing Record 477 | Alyangula
# Processing Record 478 | Constitucion
# City not found. Skipping...
# Processing Record 480 | Eureka
# Processing Record 481 | Portland
# Processing Record 482 | Emba
# Processing Record 483 | Ostrovnoy
# Processing Record 484 | Inirida
# Processing Record 485 | Saint-Pierre
# Processing Record 486 | Avera
# Processing Record 487 | Koumac
# Processing Record 488 | Kupang
# Processing Record 489 | Nyurba
# Processing Record 490 | Chauk
# Processing Record 491 | Bilma
# Processing Record 492 | Ayan
# Processing Record 493 | Kirove
# Processing Record 494 | Tromso
# Processing Record 495 | Verkhoyansk
# Processing Record 496 | Muros
# Processing Record 497 | Ust-Kut
# Processing Record 498 | Calama
# Processing Record 499 | Erzin
# Processing Record 500 | Ridgecrest
# Processing Record 501 | Swan River
# Processing Record 502 | Leshukonskoye
# Processing Record 503 | Hualmay
# Processing Record 504 | Vidim
# Processing Record 505 | Kutum
# Processing Record 506 | Yarada
# Processing Record 507 | Kalmunai
# Processing Record 508 | Fillan
# Processing Record 509 | Sihora
# Processing Record 510 | Jinxiang
# Processing Record 511 | Praia
# Processing Record 512 | Coahuayana
# Processing Record 513 | Auki
# Processing Record 514 | Sistranda
# Processing Record 515 | Tiarei
# Processing Record 516 | Te Anau
# Processing Record 517 | Plotnikovo
# Processing Record 518 | Kadungora
# Processing Record 519 | Cantapoy
# Processing Record 520 | Kysyl-Syr
# Processing Record 521 | Thinadhoo
# Processing Record 522 | Narok
# Processing Record 523 | Ballina
# Processing Record 524 | Paita
# Processing Record 525 | Kamina
# Processing Record 526 | Alice Springs
# City not found. Skipping...
# Processing Record 528 | Konya
# Processing Record 529 | Praia da Vitoria
# Processing Record 530 | Sivaki
# Processing Record 531 | Orel
# Processing Record 532 | Valparaiso
# Processing Record 533 | Saint-Augustin
# Processing Record 534 | Flinders
# Processing Record 535 | Kattivakkam
# City not found. Skipping...
# Processing Record 537 | Sungairaya
# Processing Record 538 | Beniganj
# Processing Record 539 | Keetmanshoop
# Processing Record 540 | Chumikan
# Processing Record 541 | San Pablo
# Processing Record 542 | Balikpapan
# Processing Record 543 | Nabire
# Processing Record 544 | Tervel
# Processing Record 545 | Jalu
# Processing Record 546 | Fort Morgan
# Processing Record 547 | Kensington
# Processing Record 548 | Eyl
# Processing Record 549 | Myre
# Processing Record 550 | Buochs
# Processing Record 551 | Shingu
# Processing Record 552 | Hofn
# Processing Record 553 | Giyon
# Processing Record 554 | Yendi
# Processing Record 555 | Belen
# Processing Record 556 | Smithers
# Processing Record 557 | Ulma
# Processing Record 558 | Leeds
# City not found. Skipping...
# Processing Record 560 | Kiunga

# %%
#check number of cities in clean city list
len(unique_cities)
# Out:
# 504

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create data frame from cities list
weather_df = pd.DataFrame(unique_cities)
weather_df = weather_df.rename(columns={0:"city"})

#set containers in new weather dataframe to hold json values
weather_df["city_id"] = ""
weather_df["date"] = ""
weather_df["lat"] = ""
weather_df["lon"] = ""
weather_df["country"] = ""
weather_df["maxTemp"] = ""
weather_df["cloudiness"] = ""
weather_df["humidity"] = ""
weather_df["windSpeed"] = ""

#display empty dataframe
weather_df.head()
# Out:
#          city city_id date lat lon country maxTemp cloudiness humidity  \
# 0      hasaki
# 1   fairbanks
# 2       airai
# 3  balkanabat
# 4       lagoa
#
#   windSpeed
# 0
# 1
# 2
# 3
# 4

# %%
#Set base URL and parameters
params = {"appid":api_key,"units":"imperial"}
url = "http://api.openweathermap.org/data/2.5/weather?"

#Loop through clean cities dataframe and append values for plot
for index,row in weather_df.iterrows():
    
    #Pull in city from list
    params["q"] = row['city']
    
    #query url with city
    response = requests.get(url,params).json()
    
    #append weather data to dataframe

    weather_df.loc[index,"city_id"] = response['id']
    weather_df.loc[index,"date"] = time.strftime("%d %b %Y", time.localtime(response['dt'])) 
    weather_df.loc[index,"lat"] = response['coord']['lat']
    weather_df.loc[index,"lon"] = response['coord']['lon']
    weather_df.loc[index,"country"] = response['sys']['country']
    weather_df.loc[index,"maxTemp"] = response['main']['temp_max']
    weather_df.loc[index,"cloudiness"] = response['clouds']['all']
    weather_df.loc[index,"humidity"] = response['main']['humidity']
    weather_df.loc[index,"windSpeed"] = response['wind']['speed']

# %%
#display full populated dataframe
weather_df.head()
# Out:
#          city  city_id         date    lat     lon country  maxTemp  \
# 0      hasaki  2112802  01 Apr 2019  35.73  140.83      JP    35.60
# 1   fairbanks  5861897  01 Apr 2019  64.84 -147.72      US    42.01
# 2       airai  1651810  01 Apr 2019  -8.93  125.41      TL    66.94
# 3  balkanabat   161616  01 Apr 2019  39.51   54.36      TM    49.48
# 4       lagoa  2267254  01 Apr 2019  37.14   -8.45      PT    61.00
#
#    cloudiness  humidity  windSpeed
# 0          20        93       2.24
# 1           1        64       4.70
# 2          24        89       1.25
# 3          20        95       8.23
# 4          20        82      13.87

# %%
#check for missing values
weather_df.count()
# Out:
# city          504
# city_id       504
# date          504
# lat           504
# lon           504
# country       504
# maxTemp       504
# cloudiness    504
# humidity      504
# windSpeed     504
# dtype: int64

# %%
#convert to correct data type for analysis

float_list = ['lat','lon','maxTemp','windSpeed']
int_list = ['cloudiness','humidity']

for column in float_list:
    weather_df[column] = weather_df[column].astype(float)
for column in int_list:
    weather_df[column] = weather_df[column].astype(int)

#check data types
weather_df.dtypes
# Out:
# city           object
# city_id         int64
# date           object
# lat           float64
# lon           float64
# country        object
# maxTemp       float64
# cloudiness      int64
# humidity        int64
# windSpeed     float64
# dtype: object

# %%
#Export weather data to csv
weather_df.to_csv("output_data/weather_01Apr2019_sample.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['lat'],weather_df['maxTemp'],marker='o',edgecolor='black')
plt.grid()
today_dt = datetime.datetime.now()
plt.title(f"City Latitude vs Max Temperature ({today_dt.strftime('%d %b %Y')}) \n Sample of 504 Cities")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("output_data/fig1_MaxTemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['lat'],weather_df['humidity'],marker='o',edgecolor='black')
plt.grid()
plt.title(f"City Latitude vs Humidity ({today_dt.strftime('%d %b %Y')}) \n Sample of 504 Cities")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("output_data/fig2_Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['lat'],weather_df['cloudiness'],marker='o',edgecolor='black')
plt.grid()
plt.title(f"City Latitude vs Cloudiness ({today_dt.strftime('%d %b %Y')}) \n Sample of 504 Cities")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("output_data/fig3_Cloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['lat'],weather_df['windSpeed'],marker='o',edgecolor='black')
plt.grid()
plt.title(f"City Latitude vs Wind Speed({today_dt.strftime('%d %b %Y')}) \n Sample of 504 Cities")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("output_data/fig4_WindSpeed.png")
plt.show()

# %% [markdown]
# #### Analysis

# %%
#There is an outlier (check the city with humidity > 200%)
weather_df[weather_df["humidity"]>200]
# Out:
#       city  city_id         date   lat    lon country  maxTemp  cloudiness  \
# 470  paita  3694112  01 Apr 2019 -5.09 -81.11      PE     62.6          40
#
#      humidity  windSpeed
# 470       290      10.25

# %%
#Descriptive stats
weather_df.describe()
# Out:
#             city_id         lat         lon     maxTemp  cloudiness  \
# count  5.040000e+02  504.000000  504.000000  504.000000  504.000000
# mean   2.751469e+06   20.524921   16.216706   57.463591   36.176587
# std    1.690724e+06   33.450614   91.429221   22.402527   34.270973
# min    4.974700e+04  -54.810000 -179.170000   -9.930000    0.000000
# 25%    1.598552e+06   -5.887500  -62.627500   41.290000    0.000000
# 50%    2.305166e+06   24.835000   19.245000   60.010000   24.000000
# 75%    3.662742e+06   47.682500   99.932500   77.000000   75.000000
# max    7.671223e+06   78.220000  179.320000   97.540000  100.000000
#
#          humidity   windSpeed
# count  504.000000  504.000000
# mean    72.017857    8.120516
# std     24.435774    5.372790
# min      7.000000    0.510000
# 25%     58.000000    3.760000
# 50%     75.500000    6.930000
# 75%     90.250000   11.197500
# max    290.000000   28.860000

# %%
#south hemisphere
weather_df.loc[weather_df['lat']==weather_df['lat'].min()]
# Out:
#        city  city_id         date    lat    lon country  maxTemp  cloudiness  \
# 13  ushuaia  3833367  01 Apr 2019 -54.81 -68.31      AR     53.6          75
#
#     humidity  windSpeed
# 13        87       5.28

# %%
#north hemisphere
weather_df.loc[weather_df['lat']==weather_df['lat'].max()]
# Out:
#              city  city_id         date    lat    lon country  maxTemp  \
# 129  longyearbyen  2729907  01 Apr 2019  78.22  15.63      NO     10.4
#
#      cloudiness  humidity  windSpeed
# 129          20        60      11.41

# %%
#max temp
weather_df.loc[weather_df['maxTemp']==weather_df['maxTemp'].max()]
# Out:
#                city  city_id         date   lat    lon country  maxTemp  \
# 122  ciudad bolivar  3645532  01 Apr 2019  8.12 -63.55      VE    97.54
#
#      cloudiness  humidity  windSpeed
# 122           0        27      14.34

# %%
#min temp
weather_df.loc[weather_df['maxTemp']==weather_df['maxTemp'].min()]
# Out:
#             city  city_id         date   lat    lon country  maxTemp  \
# 210  deputatskiy  2028164  01 Apr 2019  69.3  139.9      RU    -9.93
#
#      cloudiness  humidity  windSpeed
# 210          24        49       5.61

# %%
#min wind speed
weather_df.loc[weather_df['windSpeed']==weather_df['windSpeed'].min()]
# Out:
#        city  city_id         date    lat    lon country  maxTemp  cloudiness  \
# 55  kichera  2022129  01 Apr 2019  55.93  110.1      RU    12.94          80
#
#     humidity  windSpeed
# 55        70       0.51

# %%
#max wind speed
weather_df.loc[weather_df['windSpeed']==weather_df['windSpeed'].max()]
# Out:
#        city  city_id         date    lat    lon country  maxTemp  cloudiness  \
# 341  torbay  6167817  01 Apr 2019  47.66 -52.73      CA     59.0          75
#
#      humidity  windSpeed
# 341        72      28.86

# %% [markdown]
# ## Visual Analysis (Figures 1-4)
#
# ----
#
# In Summary, there is a correlation between latitude with temperature and humidity. As the sample shows (Figure 1 & 2), higher temperature and increase of humidity are concentrated with cities are around the equator (0 degrees latitude). There is almost no relationship between cloudiness and latitude, and just a slight trend of wind speed increasing as you go further away from the equator.
#
# Our sample consisted of 504 cities with varying latitudes from -54.81 degrees in Ushuala (53.6 F), Argentina to +78.22 degrees in Longyearbyen (10.4 F), Norway. Temperature in the sample varied from scorching 97.54 F in Cludad Bolivar, Venezuela (latitude 8.12) to below freezing -9.93 F in Deputatskly, Russia (latitude 69.3).
#
# ## temperature
#
# * The equator is on 0 degrees latitude. Figure 1 displays max temperature (F) with city's latitude. We can see from the curve of the scatter plot, the temperature around the equator at this time of 01 Apr 2019 is higher then the north and the sourthern hemisphere.
#
# * Interestingly at this time of the year, the temperature is colder in the northern hemisphere then the southern hemisphere. This may be due to the tilt of the earth from the sun.
#
#
# ## humidity
#
# * A city close to the equator, Paita, Peru (latitude -5, max temperature 62.6 F) is an outlier when visualizing figure 2 humidity. Although its neighboring cities has strong humidity bands near 100%, it outshines or outhumes other cities with humidity at 290%.
#
# * Humidity follows a similar correlation to temperature where closer to the equator higher the humidity and away from the equator the humidity % decreases.
#
# ## cloudiness
#
# * We cannot discern any correlation of cloudiness with latitude. Cloudiness is dispersed throughout the hemispheres. Further analysis should be done to test other factors then latitude to forecast cloudiness in cities.
#
# ## wind speed
#
# * In figure 4, we can see cities closer to the equator has a lower wind speed then the cities away from the equator. However, wind speed doesn't have as of a strong correlation as temperature and humidity. For example, minimum wind speed in our sample is from Kichera, Russia at 0.51 mph and maximum wind speed in our sample is from Torbay, England at 28.86 mph. However, these two cities are not vastly different in terms of latitude with Kichera on 55.9 degrees and Torbay on 47.66 degrees.
